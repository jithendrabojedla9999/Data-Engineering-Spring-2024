# %%
#Mount to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
#Loading the dataset
file_path = "/content/drive/MyDrive/acs2017_census_tract_data.csv.gz"
df1 = pd.read_csv(file_path, compression='gzip')
df1.head()
# Out:
#       TractId    State          County  TotalPop   Men  Women  Hispanic  \
# 0  1001020100  Alabama  Autauga County      1845   899    946       2.4
# 1  1001020200  Alabama  Autauga County      2172  1167   1005       1.1
# 2  1001020300  Alabama  Autauga County      3385  1533   1852       8.0
# 3  1001020400  Alabama  Autauga County      4267  2001   2266       9.6
# 4  1001020500  Alabama  Autauga County      9965  5054   4911       0.9
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   86.3    5.2     0.0  ...   0.5          0.0         2.1         24.5
# 1   41.6   54.5     0.0  ...   0.0          0.5         0.0         22.2
# 2   61.4   26.5     0.6  ...   1.0          0.8         1.5         23.1
# 3   80.3    7.1     0.5  ...   1.5          2.9         2.1         25.9
# 4   77.5   16.4     0.0  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0       881         74.2        21.2           4.5         0.0           4.6
# 1       852         75.9        15.0           9.0         0.0           3.4
# 2      1482         73.3        21.1           4.8         0.7           4.7
# 3      1849         75.8        19.7           4.5         0.0           6.1
# 4      4787         71.4        24.1           4.5         0.0           2.3
#
# [5 rows x 37 columns]

# %%
#Loading the dataset
file_path = "/content/drive/MyDrive/COVID_county_data.csv.gz"
df2 = pd.read_csv(file_path, compression='gzip')
df2.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
# Filter and select the required columns from the ACS data
required_columns = ['County', 'State', 'TotalPop', 'IncomePerCap', 'Poverty']
df1_filtered = df1[required_columns].copy()

# Create a new column 'ID' as a unique identifier for the county
df1_filtered['ID'] = range(len(df1_filtered))

# Group the data by 'County' and 'State' and aggregate the values using appropriate aggregation functions
aggregated_data = df1_filtered.groupby(['County', 'State']).agg({'TotalPop': 'sum', 'IncomePerCap': 'mean', 'Poverty': 'mean'})

# Reset the index of the aggregated DataFrame
County_Info = aggregated_data.reset_index()

# Rename the columns to match the desired column names
County_Info.rename(columns={'County': 'county','TotalPop': 'Population', 'IncomePerCap': 'PerCapitaIncome'}, inplace=True)

# Reset the 'ID' column to start from 1
County_Info['ID'] = County_Info.index + 1
# column_order = ['ID', 'Name', 'State', 'Population', 'Poverty', 'PerCapitaIncome']
# County_Info = County_Info[column_order]
County_Info
# Out:
#                 county           State  Population  PerCapitaIncome  \
# 0     Abbeville County  South Carolina       24788     19402.833333
# 1        Acadia Parish       Louisiana       62607     21454.250000
# 2      Accomack County        Virginia       32840     24769.750000
# 3           Ada County           Idaho      435117     32672.661017
# 4         Adair County            Iowa        7192     28840.666667
# ...                ...             ...         ...              ...
# 3215       Yuma County         Arizona      204281     21479.641509
# 3216       Yuma County        Colorado       10109     24841.000000
# 3217     Zapata County           Texas       14415     17884.333333
# 3218     Zavala County           Texas       12152     12660.250000
# 3219    Ziebach County    South Dakota        2837     13461.000000
#
#         Poverty    ID
# 0     22.183333     1
# 1     21.933333     2
# 2     20.112500     3
# 3     12.608475     4
# 4      9.566667     5
# ...         ...   ...
# 3215  19.357692  3216
# 3216  14.350000  3217
# 3217  32.566667  3218
# 3218  41.375000  3219
# 3219  43.100000  3220
#
# [3220 rows x 6 columns]

# %%
import pandas as pd

county_inputs = ["Loudoun County, Virginia", "Washington County, Oregon", "Harlan County, Kentucky", "Malheur County, Oregon"]

county_details_list = []  # List to store details dataframes

for input_county in county_inputs:
    county_name, state_name = input_county.split(", ")
    details = County_Info[(County_Info['county'] == county_name) & (County_Info['State'] == state_name)]
    county_details_list.append(details)  # Append each details dataframe to the list

county_details = pd.concat(county_details_list, ignore_index=True)  # Concatenate all dataframes in the list

print(county_details)
# Out:
#               county     State  Population  PerCapitaIncome    Poverty    ID
# 0     Loudoun County  Virginia      374558     50391.015625   3.884375  1760
# 1  Washington County    Oregon      572071     34970.817308  10.446154  3047
# 2      Harlan County  Kentucky       27548     16010.363636  33.318182  1235
# 3     Malheur County    Oregon       30421     17966.428571  24.414286  1823

# %%
# Most populous county
most_populous_county = County_Info.loc[County_Info['Population'].idxmax()]

# Least populous county
least_populous_county = County_Info.loc[County_Info['Population'].idxmin()]

most_populous_county, least_populous_county
# Out:
# (county             Los Angeles County
#  State                      California
#  Population                   10105722
#  PerCapitaIncome          31389.413867
#  Poverty                     17.323803
#  ID                               1758
#  Name: 1757, dtype: object,
#  county             Loving County
#  State                      Texas
#  Population                    74
#  PerCapitaIncome          35530.0
#  Poverty                     17.1
#  ID                          1765
#  Name: 1764, dtype: object)

# %%
# Assuming the dataset is stored in a DataFrame called 'df2'
df2['ID'] = df2['county'] + '_' + df2['state']
df2['ID'] = pd.factorize(df2['ID'])[0] + 1
df2
# Out:
#                date      county       state     fips  cases  deaths    ID
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0     1
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0     1
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0     1
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0     2
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0     1
# ...             ...         ...         ...      ...    ...     ...   ...
# 1050253  2021-02-20  Sweetwater     Wyoming  56037.0   3645    34.0  1357
# 1050254  2021-02-20       Teton     Wyoming  56039.0   3318     9.0   640
# 1050255  2021-02-20       Uinta     Wyoming  56041.0   2024    12.0  2305
# 1050256  2021-02-20    Washakie     Wyoming  56043.0    876    26.0  1784
# 1050257  2021-02-20      Weston     Wyoming  56045.0    619     5.0  3076
#
# [1050258 rows x 7 columns]

# %%
df2['date'] = pd.to_datetime(df2['date'], format='%Y-%m-%d')
df2['month'] = df2['date'].dt.to_period('M')
df2
# Out:
#               date      county       state     fips  cases  deaths    ID  \
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0     1
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0     1
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0     1
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0     2
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0     1
# ...            ...         ...         ...      ...    ...     ...   ...
# 1050253 2021-02-20  Sweetwater     Wyoming  56037.0   3645    34.0  1357
# 1050254 2021-02-20       Teton     Wyoming  56039.0   3318     9.0   640
# 1050255 2021-02-20       Uinta     Wyoming  56041.0   2024    12.0  2305
# 1050256 2021-02-20    Washakie     Wyoming  56043.0    876    26.0  1784
# 1050257 2021-02-20      Weston     Wyoming  56045.0    619     5.0  3076
#
#            month
# 0        2020-01
# 1        2020-01
# 2        2020-01
# 3        2020-01
# 4        2020-01
# ...          ...
# 1050253  2021-02
# 1050254  2021-02
# 1050255  2021-02
# 1050256  2021-02
# 1050257  2021-02
#
# [1050258 rows x 8 columns]

# %%
df2_monthly = df2.groupby(['ID', 'month']).agg({
    'cases': 'sum',
    'deaths': 'sum',
    'county': 'first'
}).reset_index()

df2_monthly['ID'] = range(1, len(df2_monthly) + 1)
df2_monthly = df2_monthly[['ID', 'month', 'cases', 'deaths', 'county']].copy()

df2_monthly.columns = ['ID', 'Month', 'cases', 'deaths', 'county']

df2_monthly
# Out:
#           ID    Month  cases  deaths     county
# 0          1  2020-01     11     0.0  Snohomish
# 1          2  2020-02     31     0.0  Snohomish
# 2          3  2020-03  11076   246.0  Snohomish
# 3          4  2020-04  58740  2366.0  Snohomish
# 4          5  2020-05  94534  3898.0  Snohomish
# ...      ...      ...    ...     ...        ...
# 37252  37253  2020-11      1     0.0    Unknown
# 37253  37254  2020-12     22     0.0    Kalawao
# 37254  37255  2021-01     31     0.0    Kalawao
# 37255  37256  2021-02     20     0.0    Kalawao
# 37256  37257  2021-01    998     0.0    Unknown
#
# [37257 rows x 5 columns]

# %%
selected_months = ['2020-08', '2021-01', '2021-02']
selected_county = 'Malheur'
covid_report = df2_monthly[(df2_monthly['county'] == selected_county) &
                              (df2_monthly['Month'].astype(str).isin(selected_months))]

print(covid_report)
# Out:
#           ID    Month  cases  deaths   county
# 25593  25594  2020-08  28163   459.0  Malheur
# 25598  25599  2021-01  96297  1627.0  Malheur
# 25599  25600  2021-02  65951  1137.0  Malheur

# %%
covid_summary = (df2_monthly.groupby("ID").agg({"cases": "sum", "deaths": "sum"}).reset_index())
covid_summary.rename(columns={"cases": "TotalCases", "deaths": "TotalDeaths"}, inplace=True)
covid_summary = pd.merge(covid_summary, County_Info, how="left", on="ID")
covid_summary["TotalCasesPer100K"] = round((covid_summary["TotalCases"]) / (covid_summary["Population"] / 100000), 2)
covid_summary["TotalDeathsPer100K"] = round((covid_summary["TotalDeaths"]) / (covid_summary["Population"] / 100000), 2)
display(covid_summary)
# Out:
#           ID  TotalCases  TotalDeaths            county           State  \
# 0          1          11          0.0  Abbeville County  South Carolina
# 1          2          31          0.0     Acadia Parish       Louisiana
# 2          3       11076        246.0   Accomack County        Virginia
# 3          4       58740       2366.0        Ada County           Idaho
# 4          5       94534       3898.0      Adair County            Iowa
# ...      ...         ...          ...               ...             ...
# 37252  37253           1          0.0               NaN             NaN
# 37253  37254          22          0.0               NaN             NaN
# 37254  37255          31          0.0               NaN             NaN
# 37255  37256          20          0.0               NaN             NaN
# 37256  37257         998          0.0               NaN             NaN
#
#        Population  PerCapitaIncome    Poverty  TotalCasesPer100K  \
# 0         24788.0     19402.833333  22.183333              44.38
# 1         62607.0     21454.250000  21.933333              49.52
# 2         32840.0     24769.750000  20.112500           33727.16
# 3        435117.0     32672.661017  12.608475           13499.82
# 4          7192.0     28840.666667   9.566667         1314432.70
# ...           ...              ...        ...                ...
# 37252         NaN              NaN        NaN                NaN
# 37253         NaN              NaN        NaN                NaN
# 37254         NaN              NaN        NaN                NaN
# 37255         NaN              NaN        NaN                NaN
# 37256         NaN              NaN        NaN                NaN
#
#        TotalDeathsPer100K
# 0                    0.00
# 1                    0.00
# 2                  749.09
# 3                  543.76
# 4                54199.11
# ...                   ...
# 37252                 NaN
# 37253                 NaN
# 37254                 NaN
# 37255                 NaN
# 37256                 NaN
#
# [37257 rows x 10 columns]

# %%
counties = [('Washington County', 'Oregon'), ('Malheur County', 'Oregon'), ('Loudoun County', 'Virginia'), ('Harlan County', 'Kentucky')]

# Filter the DataFrame based on the specified counties
filtered_df = covid_summary[
    (covid_summary['county'].isin([county[0] for county in counties])) &
    (covid_summary['State'].isin([county[1] for county in counties]))
]

# Extract the 'Poverty%' and 'TotalCasesPer100K' values for the specified counties
poverty_percentage = filtered_df[['county', 'State', 'Poverty']]
total_cases_per_100k = filtered_df[['county', 'State', 'TotalCasesPer100K']]

# Print the results
print("Poverty Percentage:")
print(poverty_percentage)
print("\nTotal Cases per 100K:")
print(total_cases_per_100k)
# Out:
# Poverty Percentage:
#                  county     State    Poverty
# 1234      Harlan County  Kentucky  33.318182
# 1759     Loudoun County  Virginia   3.884375
# 1822     Malheur County    Oregon  24.414286
# 3035  Washington County  Kentucky  16.900000
# 3046  Washington County    Oregon  10.446154
# 3053  Washington County  Virginia  14.715385
#
# Total Cases per 100K:
#                  county     State  TotalCasesPer100K
# 1234      Harlan County  Kentucky         1671979.82
# 1759     Loudoun County  Virginia            3086.84
# 1822     Malheur County    Oregon          542792.81
# 3035  Washington County  Kentucky          178864.91
# 3046  Washington County    Oregon           61741.46
# 3053  Washington County  Virginia              55.09

# %%
oregon_county = covid_summary[covid_summary['State'] == 'Oregon']
print(oregon_county)
# Out:
#         ID  TotalCases  TotalDeaths             county   State  Population  \
# 126    127      176630       7094.0       Baker County  Oregon     15980.0
# 197    198      269042       2377.0      Benton County  Oregon     88249.0
# 533    534       64549       2655.0   Clackamas County  Oregon    399962.0
# 558    559      165400       8893.0     Clatsop County  Oregon     38021.0
# 631    632        9177        720.0    Columbia County  Oregon     50207.0
# 656    657       25645        265.0        Coos County  Oregon     62921.0
# 697    698     1099390      19381.0       Crook County  Oregon     21717.0
# 718    719      294898       2637.0       Curry County  Oregon     22377.0
# 796    797         455         21.0   Deschutes County  Oregon    175321.0
# 839    840      513374       8400.0     Douglas County  Oregon    107576.0
# 1068  1069     1247029      27789.0     Gilliam County  Oregon      1910.0
# 1115  1116       11712         93.0       Grant County  Oregon      7209.0
# 1238  1239     1876864      22827.0      Harney County  Oregon      7195.0
# 1320  1321       19490        369.0  Hood River County  Oregon     22938.0
# 1415  1416      347301      12011.0     Jackson County  Oregon    212070.0
# 1453  1454      125321       2101.0   Jefferson County  Oregon     22707.0
# 1493  1494      146281       6744.0   Josephine County  Oregon     84514.0
# 1559  1560      594520      20882.0     Klamath County  Oregon     66018.0
# 1608  1609       53869        409.0        Lake County  Oregon      7807.0
# 1626  1627       24937        776.0        Lane County  Oregon    363471.0
# 1720  1721         707         29.0     Lincoln County  Oregon     47307.0
# 1731  1732      985452      14914.0        Linn County  Oregon    121074.0
# 1822  1823      165123       3872.0     Malheur County  Oregon     30421.0
# 1848  1849      394112       6060.0      Marion County  Oregon    330453.0
# 2070  2071        7148        145.0      Morrow County  Oregon     11153.0
# 2078  2079      500621       4240.0   Multnomah County  Oregon    788459.0
# 2359  2360        8401        241.0        Polk County  Oregon     79666.0
# 2671  2672        2448         30.0     Sherman County  Oregon      1635.0
# 2860  2861        9148         17.0   Tillamook County  Oregon     25840.0
# 2919  2920     1823532      16315.0    Umatilla County  Oregon     76736.0
# 2933  2934        5862        454.0       Union County  Oregon     25810.0
# 2994  2995       43886       1044.0     Wallowa County  Oregon      6864.0
# 3021  3022       20054        524.0       Wasco County  Oregon     25687.0
# 3046  3047      353205       5844.0  Washington County  Oregon    572071.0
# 3109  3110     1327277      18188.0     Wheeler County  Oregon      1415.0
# 3195  3196       34918        380.0     Yamhill County  Oregon    102366.0
#
#       PerCapitaIncome    Poverty  TotalCasesPer100K  TotalDeathsPer100K
# 126      25706.833333  15.000000         1105319.15            44392.99
# 197      29926.000000  23.644444          304866.91             2693.51
# 533      37502.712500   9.320000           16138.78              663.81
# 558      28357.363636  12.481818          435022.75            23389.71
# 631      28109.700000  12.530000           18278.33             1434.06
# 656      26488.307692  17.415385           40757.46              421.16
# 697      23958.500000  15.050000         5062347.47            89243.45
# 718      26899.200000  16.300000         1317862.09            11784.42
# 796      31834.375000  12.208333             259.52               11.98
# 839      25208.545455  16.731818          477219.83             7808.43
# 1068     24178.000000   9.900000        65289476.44          1454921.47
# 1115     23855.000000  15.850000          162463.59             1290.05
# 1238     25174.500000  16.300000        26085670.60           317261.99
# 1320     29178.000000  12.150000           84968.18             1608.68
# 1415     27328.780488  17.882927          163767.15             5663.70
# 1453     22689.666667  20.316667          551904.70             9252.65
# 1493     24179.062500  19.131250          173084.93             7979.74
# 1559     23712.400000  18.930000          900542.28            31630.77
# 1608     21121.500000  19.200000          690008.97             5238.89
# 1626     27546.220930  18.529070            6860.79              213.50
# 1720     26807.411765  17.623529            1494.49               61.30
# 1731     24452.714286  16.923810          813925.37            12318.09
# 1822     17966.428571  24.414286          542792.81            12728.05
# 1848     25903.862069  15.329310          119264.16             1833.85
# 2070     23171.500000  13.450000           64090.38             1300.10
# 2078     36739.558824  15.730588           63493.60              537.76
# 2359     24633.916667  18.641667           10545.28              302.51
# 2671     34226.000000  13.700000          149724.77             1834.86
# 2860     25805.750000  15.437500           35402.48               65.79
# 2919     23200.466667  16.520000         2376370.93            21261.21
# 2933     26508.875000  17.425000           22712.13             1759.01
# 2994     26943.000000  14.400000          639364.80            15209.79
# 3021     25089.750000  13.037500           78070.62             2039.94
# 3046     34970.817308  10.446154           61741.46             1021.55
# 3109     21268.000000  20.600000        93800494.70          1285371.02
# 3195     28578.882353  13.935294           34110.94              371.22

# %%
#COVID total cases vs. % population in poverty

analysis_1a = oregon_county['TotalCases'].corr(oregon_county['Poverty'])
print(analysis_1a)
# Out:
# 0.05448687198634776

# %%
#COVID total deaths vs. % population in poverty

analysis_1b = oregon_county['TotalDeaths'].corr(oregon_county['Poverty'])
print(analysis_1b)
# Out:
# -0.003927649458842

# %%
#COVID total cases vs. Per Capita Income level

analysis_1c = oregon_county['TotalCases'].corr(oregon_county['PerCapitaIncome'])
print(analysis_1c)
# Out:
# -0.2557187510018219

# %%
#COVID total deaths vs. Per Capita Income level

analysis_1d = oregon_county['TotalDeaths'].corr(oregon_county['PerCapitaIncome'])
print(analysis_1d)
# Out:
# -0.2878717772723963

# %%
#COVID total cases vs. % population in poverty

r2 = covid_summary['TotalCases'].corr(covid_summary['Poverty'])
print(r2)
# Out:
# 0.02172395775348989

# %%
#COVID total deaths vs. % population in poverty

r2 = covid_summary['TotalDeaths'].corr(covid_summary['Poverty'])
print(r2)
# Out:
# 0.00988447825942164

# %%
#COVID total cases vs. Per Capita Income level

r2 = covid_summary['TotalCases'].corr(covid_summary['PerCapitaIncome'])
print(r2)
# Out:
# -0.02544712849260708

# %%
#COVID total deaths vs. Per Capita Income level

r2 = covid_summary['TotalDeaths'].corr(covid_summary['PerCapitaIncome'])
print(r2)
# Out:
# -0.01255471625709621
