# %%
# !pip install faker

import faker
import random
import pandas as pd

# Initialize Faker
fake = faker.Faker()
fake_usa = faker.Faker('en_US')
fake_india = faker.Faker('en_IN')
fake_china = faker.Faker('zh_CN')
fake_canada = faker.Faker('en_CA')
fake_korea = faker.Faker('ko_KR')
fake_philippines = faker.Faker('en_PH')
fake_taiwan = faker.Faker('zh_TW')
fake_mexico = faker.Faker('es_MX')

# Constants
NUM_EMPLOYEES = 10000
DEPARTMENTS = {
    "Legal": 0.05,
    "Marketing": 0.10,
    "Administrative": 0.10,
    "Operations": 0.20,
    "Sales": 0.10,
    "Finance": 0.05,
    "I/T": 0.10,
    "Product": 0.20,
    "Human Resource": 0.10
}

SALARY_RANGES = {
    "Legal": (60000, 200000),
    "Marketing": (50000, 150000),
    "Administrative": (40000, 100000),
    "Operations": (50000, 150000),
    "Sales": (40000, 120000),
    "Finance": (50000, 150000),
    "I/T": (60000, 180000),
    "Product": (70000, 200000),
    "Human Resource": (50000, 120000)
}

H1B_COUNTRIES = {
    "India": 0.72,
    "China": 0.13,
    "Canada": 0.04,
    "South Korea": 0.03,
    "Philippines": 0.02,
    "Taiwan": 0.01,
    "Mexico": 0.01
}

LANGUAGES = ["Spanish", "Mandarin", "Hindi", "French", "German", "Korean", "Tagalog"]

# Generate Data
employees = []
ssn_set = set()

for _ in range(NUM_EMPLOYEES):
    # Generate social security number ensuring uniqueness
    ssn = fake_usa.ssn()
    while ssn in ssn_set:
        ssn = fake_usa.ssn()
    ssn_set.add(ssn)

    # Determine citizenship and name
    if random.random() < 0.40:
        country = random.choices(list(H1B_COUNTRIES.keys()), weights=H1B_COUNTRIES.values(), k=1)[0]
        if country == "India":
            first_name, last_name = fake_india.first_name(), fake_india.last_name()
        elif country == "China":
            first_name, last_name = fake_china.first_name(), fake_china.last_name()
        elif country == "Canada":
            first_name, last_name = fake_canada.first_name(), fake_canada.last_name()
        elif country == "South Korea":
            first_name, last_name = fake_korea.first_name(), fake_korea.last_name()
        elif country == "Philippines":
            first_name, last_name = fake_philippines.first_name(), fake_philippines.last_name()
        elif country == "Taiwan":
            first_name, last_name = fake_taiwan.first_name(), fake_taiwan.last_name()
        elif country == "Mexico":
            first_name, last_name = fake_mexico.first_name(), fake_mexico.last_name()
        citizenship = country
    else:
        first_name, last_name = fake_usa.first_name(), fake_usa.last_name()
        citizenship = "USA"

    # Assign gender to balance male and female employees
    gender = random.choice(["Male", "Female"])

    # Generate additional fields
    email = fake.email()
    phone = fake.phone_number()
    age = random.randint(22, 65)
    years_of_experience = random.randint(0, age - 21)  # assuming people start working at 21
    department = random.choices(list(DEPARTMENTS.keys()), weights=DEPARTMENTS.values(), k=1)[0]
    salary_range = SALARY_RANGES[department]
    salary = round(random.uniform(salary_range[0], salary_range[1]), 2)
    num_languages = random.choices([0, 1, 2], weights=[0.6, 0.3, 0.1], k=1)[0]
    languages_spoken = ", ".join(random.sample(LANGUAGES, num_languages))
    job_title = fake.job()

    employees.append({
        "First Name": first_name,
        "Last Name": last_name,
        "Email": email,
        "Phone": phone,
        "Gender": gender,
        "Age": age,
        "Job Title": job_title,
        "Years Of Experience": years_of_experience,
        "Salary": salary,
        "Department": department,
        "Languages": languages_spoken
    })

# Convert to DataFrame and save to CSV
df = pd.DataFrame(employees)
df.to_csv('/content/employees.csv', index=False)

# Print the columns to verify
print("Column names in the generated CSV file:")
print(df.columns)
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.10/dist-packages (25.8.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Column names in the generated CSV file:
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Gender', 'Age',
#        'Job Title', 'Years Of Experience', 'Salary', 'Department',
#        'Languages'],
#       dtype='object')

# %%
import pandas as pd

# Constants
NUM_EMPLOYEES = 10000
DEPARTMENTS = {
    "Legal": 0.05,
    "Marketing": 0.10,
    "Administrative": 0.10,
    "Operations": 0.20,
    "Sales": 0.10,
    "Finance": 0.05,
    "I/T": 0.10,
    "Product": 0.20,
    "Human Resource": 0.10
}

# Calculate number of employees per department
department_counts = {dept: int(NUM_EMPLOYEES * proportion) for dept, proportion in DEPARTMENTS.items()}

# Calculate number of men and women per department
gender_distribution = {dept: {"Men": count // 2, "Women": count // 2} for dept, count in department_counts.items()}

# Display the gender distribution
gender_distribution_df = pd.DataFrame(gender_distribution).T
gender_distribution_df
# Out:
#                  Men  Women
# Legal            250    250
# Marketing        500    500
# Administrative   500    500
# Operations      1000   1000
# Sales            500    500
# Finance          250    250
# I/T              500    500
# Product         1000   1000
# Human Resource   500    500

# %%
# Salary ranges for each department
SALARY_RANGES = {
    "Legal": (60000, 200000),
    "Marketing": (50000, 150000),
    "Administrative": (40000, 100000),
    "Operations": (50000, 150000),
    "Sales": (40000, 120000),
    "Finance": (50000, 150000),
    "I/T": (60000, 180000),
    "Product": (70000, 200000),
    "Human Resource": (50000, 120000)
}

# Calculate average salary for each department
average_salaries = {dept: (range_[0] + range_[1]) / 2 for dept, range_ in SALARY_RANGES.items()}

# Calculate total payroll for each department
total_payroll = {dept: count * average_salaries[dept] for dept, count in department_counts.items()}

# Calculate overall yearly payroll
yearly_payroll = sum(total_payroll.values())

yearly_payroll
# Out:
# 1040000000.0

# %%
# Number of employees
num_employees = len(df)

# Average office space per employee (in square feet)
average_space_per_employee = 150  # This can be adjusted based on company requirements

# Total office space required
total_office_space = num_employees * average_space_per_employee

print(f"Total office space required: {total_office_space:,} square feet")
# Out:
# Total office space required: 1,500,000 square feet

# %%
import pandas as pd
import numpy as np

# Load the generated CSV file (if not already loaded)
# df = pd.read_csv('/content/employee_1.csv')

# Define the age range and bias factor
age_range = range(40, 50)
bias_factor = 3

# Calculate the weights
weights = np.where(df['Age'].isin(age_range), bias_factor, 1)

# Normalize the weights to sum to 1
weights = weights / weights.sum()

# Generate the biased sample
biased_sample = df.sample(n=20, weights=weights, random_state=42)

# Display the biased sample
#print(biased_sample)
biased_sample
# Out:
#      First Name Last Name                     Email                  Phone  \
# 3793      Hunar        De     vgonzalez@example.org      (395)640-2538x235
# 9492     Suhana      Keer     michael95@example.org       599-563-7144x433
# 7359     Sandra     Huang  melindabanks@example.org             3599202306
# 6007    Nichole      Ford    ruizshelby@example.org             5548355246
# 1557      Karen    Tucker      wkennedy@example.org           740.859.2145
# 586     Stephen     Ramos       awilson@example.com           898-592-7645
# 8694     Khushi    Tandon       logan42@example.com           743-925-4008
# 6032    Valerie    Tanner     wwilliams@example.net     635-539-4839x51947
# 7114   Priyansh     Dewan        bjames@example.net           541-947-2928
# 216          秀荣         刘   shellyfloyd@example.net           456-577-9897
# 9678    Bhamini       Sen        mary11@example.com       388-605-0001x545
# 8355    Matthew  Odonnell      tonyross@example.net    +1-791-403-3763x691
# 2137      James      Dean   wardclinton@example.com   +1-369-228-6873x6642
# 1828         桂芝         史        sperry@example.org   001-736-784-7308x221
# 1845      Aaron    Dennis      brenda38@example.com          (751)426-1492
# 3056  Dharmajan     Chada    moodykaren@example.com      (751)745-4642x473
# 5269   Neelofar      Tata   amandasmith@example.com           916.954.8073
# 4353     Darren   Stewart   yatesevelyn@example.net  001-714-919-8665x5964
# 2925      Jason     Woods    hpatterson@example.net      709.325.3860x7869
# 6149       Lisa    Butler  walshrebecca@example.net        +1-769-687-1733
#
#       Gender  Age                                          Job Title  \
# 3793  Female   65                                             Lawyer
# 9492  Female   40                                      Hotel manager
# 7359    Male   27                            Chief Operating Officer
# 6007    Male   62                             Chief Strategy Officer
# 1557  Female   23                                 Field seismologist
# 586   Female   45                           Computer games developer
# 8694  Female   39                              Journalist, newspaper
# 6032    Male   41                           Doctor, general practice
# 7114  Female   35                           Educational psychologist
# 216   Female   33                          Engineer, technical sales
# 9678  Female   54                              Agricultural engineer
# 8355    Male   53                                  Fish farm manager
# 2137  Female   47                           Surveyor, land/geomatics
# 1828  Female   59                           Television floor manager
# 1845  Female   40  Historic buildings inspector/conservation officer
# 3056    Male   40                                   Technical author
# 5269    Male   47                          Higher education lecturer
# 4353  Female   40                                   Surveyor, mining
# 2925    Male   56                              Administrator, sports
# 6149    Male   22                                 Theme park manager
#
#       Years Of Experience     Salary      Department Languages
# 3793                   35  110795.47             I/T
# 9492                   15  161142.21         Product
# 7359                    0   74158.00         Product   Tagalog
# 6007                   37  144367.39         Product    Korean
# 1557                    0  142406.55       Marketing    German
# 586                     4   57027.02       Marketing
# 8694                    1   98263.61  Human Resource   Spanish
# 6032                   16  100519.54           Sales
# 7114                    8  126631.01             I/T
# 216                     9   81999.40             I/T   Tagalog
# 9678                    3   70791.46             I/T
# 8355                   18   81098.28         Finance
# 2137                   18   83657.36           Sales  Mandarin
# 1828                   12   68806.39      Operations  Mandarin
# 1845                   15   80962.93           Sales
# 3056                   19  146896.71           Legal
# 5269                   15  147347.51      Operations    French
# 4353                    3  142778.07       Marketing
# 2925                    4   77104.42         Finance
# 6149                    1   63067.53           Sales

# %%
import faker

# Initialize Faker
fake = faker.Faker()

# Anonymize the data
df['First Name'] = [fake.first_name() for _ in range(len(df))]
df['Last Name'] = [fake.last_name() for _ in range(len(df))]
df['Email'] = [fake.email() for _ in range(len(df))]
df['Phone'] = [fake.phone_number() for _ in range(len(df))]

# Display the anonymized sample
#print(df.sample(20))
df.sample(20)
# Out:
#      First Name   Last Name                        Email  \
# 2953    Raymond      Thomas  richmondmatthew@example.net
# 872       Brian     Johnson   pamelamartinez@example.net
# 3888      James        Ward             gray@example.net
# 9738      Kevin       Brown          pmurray@example.com
# 3906    Charles       Smith     bradleyjason@example.com
# 9090       Lisa   Singleton         fbarrett@example.net
# 8422    William    Crawford           sean69@example.net
# 3123    Michael  Livingston           kari23@example.org
# 4710       Anna     Gardner        ogonzalez@example.net
# 8658    Carolyn   Gallagher           zbryan@example.org
# 6731       Paul       Berry            bsoto@example.net
# 2908    Tiffany        Reed       edwardmoss@example.org
# 5979    Whitney        Shah         dustin11@example.net
# 9833      Steve       Huber    heatherpeters@example.org
# 5744       Lori      Flores          kfarmer@example.net
# 4132      Sarah     Sellers           psalas@example.org
# 1094   Patricia      Dillon          lmiller@example.org
# 3823      Tyler      Garner        jessica27@example.net
# 5874    Deborah    Whitaker        ajohnston@example.com
# 3220    Tiffany    Cisneros       markfrench@example.com
#
#                        Phone  Gender  Age  \
# 2953              4398867897    Male   31
# 872               8702368535    Male   57
# 3888         +1-722-824-9193  Female   37
# 9738  001-433-908-6733x07504    Male   32
# 3906            464.340.3204  Female   47
# 9090            588.610.0347    Male   22
# 8422     +1-708-836-3416x824  Female   60
# 3123              5303349740    Male   33
# 4710           (896)350-4157  Female   23
# 8658      731.967.6244x61889    Male   28
# 6731            269-888-6872  Female   51
# 2908    001-627-821-8964x440  Female   24
# 5979   +1-714-976-9288x21365    Male   47
# 9833    +1-541-813-7424x5457  Female   37
# 5744    +1-875-858-8147x9068    Male   26
# 4132           (627)332-4267    Male   35
# 1094            350.572.0636  Female   48
# 3823            605-468-7349    Male   36
# 5874   +1-938-557-0829x74285  Female   33
# 3220      319.850.6660x31942    Male   58
#
#                                           Job Title  Years Of Experience  \
# 2953                       Print production planner                    0
# 872                                    Psychiatrist                    3
# 3888                        Data processing manager                    7
# 9738                             Production manager                    7
# 3906                                Legal executive                   13
# 9090                            Trade mark attorney                    0
# 8422                                 Energy manager                   35
# 3123                           Nurse, mental health                   12
# 4710                        Chartered loss adjuster                    1
# 8658                      Building control surveyor                    1
# 6731                               Therapist, drama                   17
# 2908                                            Sub                    1
# 5979                           Maintenance engineer                    0
# 9833                                    Ship broker                   12
# 5744  Chartered legal executive (England and Wales)                    1
# 4132                            Landscape architect                    4
# 1094                        Secretary/administrator                    8
# 3823                             Purchasing manager                    5
# 5874                        Chartered loss adjuster                    3
# 3220        Scientist, research (physical sciences)                   13
#
#          Salary      Department        Languages
# 2953   69360.89  Administrative           French
# 872    91186.58  Administrative
# 3888   53390.34  Administrative  German, Spanish
# 9738   81936.88      Operations
# 3906  146324.32             I/T
# 9090  112510.70           Sales          Tagalog
# 8422  157032.78         Product
# 3123  168677.22         Product
# 4710  108786.29         Product
# 8658  109952.72             I/T
# 6731  139942.64         Product           French
# 2908   70708.38         Product          Tagalog
# 5979   55859.94         Finance   Spanish, Hindi
# 9833   85819.61  Human Resource
# 5744  107572.14  Human Resource           French
# 4132  124145.46       Marketing            Hindi
# 1094   90406.10      Operations  Spanish, French
# 3823   73816.52             I/T
# 5874  115067.19           Sales           Korean
# 3220   71357.91  Administrative

# %%
import numpy as np

# Define standard deviation parameters
sigma_age = 3  # Small variability for age
sigma_salary = df['Salary'].mean() * 0.1  # 10% of the mean salary
sigma_experience = 2  # Moderate variability for years of experience

# Perturb the attributes using Gaussian noise
df['Age'] = df['Age'] + np.random.normal(0, sigma_age, df['Age'].shape)
df['Salary'] = df['Salary'] + np.random.normal(0, sigma_salary, df['Salary'].shape)
df['Years Of Experience'] = df['Years Of Experience'] + np.random.normal(0, sigma_experience, df['Years Of Experience'].shape)

# Ensure the values remain realistic
df['Age'] = df['Age'].clip(lower=18)  # Assuming a minimum age of 18
df['Years Of Experience'] = df['Years Of Experience'].clip(lower=0)  # Experience cannot be negative
df['Salary'] = df['Salary'].clip(lower=0)  # Salary cannot be negative

# Display the perturbed sample
perturbed_sample = df.sample(20)
perturbed_sample
# Out:
#      First Name  Last Name                          Email  \
# 9131      Amber      Yates              kim50@example.net
# 9545      Devin       Odom            tanya55@example.org
# 7390     Monica    Johnson         crobertson@example.org
# 8237     Steven      Davis            angel69@example.org
# 8468      David      Moore            qlawson@example.net
# 3372     Cheryl   Richards           alexis17@example.com
# 4024     Daniel      Lynch   victoriamcdowell@example.org
# 4778     Pamela     Garcia    elizabethtaylor@example.net
# 212       Diane       Hall             uperez@example.net
# 7902      Sheri     Wright            tmiller@example.org
# 2242    Russell   Reynolds           jeremy56@example.org
# 6626     Nathan    Gardner      sandersamanda@example.com
# 5696       Erik     Brooks  christopherbryant@example.net
# 6838    William   Gonzalez            bruce07@example.net
# 5570       Evan      Bowen             vsmith@example.net
# 9086     Ashley       Rich           ejackson@example.net
# 8577      Debra  Gutierrez         loriwilson@example.com
# 249      Brandy     Walker          clinegary@example.org
# 8359      Jesse       Love             pyoung@example.com
# 7308       Sara       Koch           travis34@example.org
#
#                      Phone  Gender        Age                       Job Title  \
# 9131   (967)750-5864x34039  Female  56.639526           Exercise physiologist
# 9545          590.534.9410  Female  42.650362            Engineer, electrical
# 7390            5923168767    Male  41.403842                   IT consultant
# 8237          648.413.9090  Female  24.360544       Consulting civil engineer
# 8468    (413)479-4966x0928  Female  51.924440            Optician, dispensing
# 3372          539-967-4357  Female  42.019027         Chief Financial Officer
# 4024          312-771-6477  Female  33.422585                    Youth worker
# 4778    600-906-5047x60186  Female  36.825394                          Gaffer
# 212          (464)431-3185    Male  29.836534                     Tax adviser
# 7902    240-369-7739x72192  Female  58.894774        Local government officer
# 2242   +1-502-825-5000x314  Female  31.001482                   Oceanographer
# 6626         (516)764-5719    Male  35.833010  Commercial art gallery manager
# 5696    372-561-9848x60041    Male  46.742047            Sports administrator
# 6838  001-931-903-8505x654    Male  62.520162               Financial adviser
# 5570       +1-644-856-9071  Female  33.517515           Volunteer coordinator
# 9086      428-584-5203x865  Female  23.502559       Occupational psychologist
# 8577          550-324-2810  Female  27.970684             Electrical engineer
# 249             9162054890    Male  49.120772     Engineer, building services
# 8359          345.506.9607  Female  44.114736      Engineer, maintenance (IT)
# 7308      001-953-577-7256  Female  39.844093        Environmental consultant
#
#       Years Of Experience         Salary      Department      Languages
# 9131            31.112685   48736.973173       Marketing         Korean
# 9545             0.000000   74951.473785             I/T
# 7390             7.818612  117444.321594           Sales
# 8237             0.000000  151735.911964         Product         German
# 8468            23.592516  108149.713953      Operations
# 3372             2.219593   71588.774178  Human Resource       Mandarin
# 4024             8.251156  141181.230556      Operations
# 4778            17.711752  103864.908121         Product
# 212              6.608164   51269.743801       Marketing
# 7902            29.066707  109038.679493           Sales
# 2242             3.006572   84838.065236  Human Resource  Hindi, Korean
# 6626             7.944901   95799.299827      Operations         French
# 5696            12.648760   67401.247327      Operations        Tagalog
# 6838            20.209723  143555.364987       Marketing
# 5570            10.667596  122093.753146             I/T
# 9086             0.000000  187002.453696         Product
# 8577            11.148435  130563.356758      Operations
# 249             10.383677   70565.644157       Marketing        Tagalog
# 8359             0.000000   88752.920290             I/T         Korean
# 7308            16.695490  122105.013201      Operations

# %%
# !pip install ydata-profiling
import pandas as pd
from ydata_profiling import ProfileReport

# Load the synthetic dataset
synthetic_df = pd.read_csv('/content/employee_1.csv')

# Generate profile for the synthetic dataset
synthetic_profile = ProfileReport(synthetic_df, title="Synthetic Dataset Profile", explorative=True)
synthetic_profile.to_file("synthetic_dataset_profile.html")

# Load the original dataset (assuming it's named 'employees.csv')
original_df = pd.read_csv('/content/employee_1.csv')

# Generate profile for the original dataset
original_profile = ProfileReport(original_df, title="Original Dataset Profile", explorative=True)
original_profile.to_file("original_dataset_profile.html")
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.7.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Collecting visions[type_image_path]<0.7.7,>=0.7.5 (from ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.25.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.1)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.11.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.3)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.58.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.6.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=dc9ecdb3241c50f0a434a8860dd2c1e5cd169d336e35899a934b242f846437d0
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.11.2 phik-0.12.4 typeguard-4.3.0 visions-0.7.6 ydata-profiling-4.8.3
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install ydata-profiling

import faker
import random
import pandas as pd
from ydata_profiling import ProfileReport

# Initialize Faker
fake = faker.Faker()
fake_usa = faker.Faker('en_US')
fake_india = faker.Faker('en_IN')
fake_china = faker.Faker('zh_CN')
fake_canada = faker.Faker('en_CA')
fake_korea = faker.Faker('ko_KR')
fake_philippines = faker.Faker('en_PH')
fake_taiwan = faker.Faker('zh_TW')
fake_mexico = faker.Faker('es_MX')

# Constants
NUM_EMPLOYEES = 10000
DEPARTMENTS = {
    "Legal": 0.05,
    "Marketing": 0.10,
    "Administrative": 0.10,
    "Operations": 0.20,
    "Sales": 0.10,
    "Finance": 0.05,
    "I/T": 0.10,
    "Product": 0.20,
    "Human Resource": 0.10
}

SALARY_RANGES = {
    "Legal": (60000, 200000),
    "Marketing": (50000, 150000),
    "Administrative": (40000, 100000),
    "Operations": (50000, 150000),
    "Sales": (40000, 120000),
    "Finance": (50000, 150000),
    "I/T": (60000, 180000),
    "Product": (70000, 200000),
    "Human Resource": (50000, 120000)
}

H1B_COUNTRIES = {
    "India": 0.72,
    "China": 0.13,
    "Canada": 0.04,
    "South Korea": 0.03,
    "Philippines": 0.02,
    "Taiwan": 0.01,
    "Mexico": 0.01
}

LANGUAGES = ["Spanish", "Mandarin", "Hindi", "French", "German", "Korean", "Tagalog"]

# Generate Data
employees = []
ssn_set = set()

for _ in range(NUM_EMPLOYEES):
    # Generate social security number ensuring uniqueness
    ssn = fake_usa.ssn()
    while ssn in ssn_set:
        ssn = fake_usa.ssn()
    ssn_set.add(ssn)

    # Determine citizenship and name
    if random.random() < 0.40:
        country = random.choices(list(H1B_COUNTRIES.keys()), weights=H1B_COUNTRIES.values(), k=1)[0]
        if country == "India":
            first_name, last_name = fake_india.first_name(), fake_india.last_name()
        elif country == "China":
            first_name, last_name = fake_china.first_name(), fake_china.last_name()
        elif country == "Canada":
            first_name, last_name = fake_canada.first_name(), fake_canada.last_name()
        elif country == "South Korea":
            first_name, last_name = fake_korea.first_name(), fake_korea.last_name()
        elif country == "Philippines":
            first_name, last_name = fake_philippines.first_name(), fake_philippines.last_name()
        elif country == "Taiwan":
            first_name, last_name = fake_taiwan.first_name(), fake_taiwan.last_name()
        elif country == "Mexico":
            first_name, last_name = fake_mexico.first_name(), fake_mexico.last_name()
        citizenship = country
    else:
        first_name, last_name = fake_usa.first_name(), fake_usa.last_name()
        citizenship = "USA"

    # Assign gender to balance male and female employees
    gender = random.choice(["Male", "Female"])

    # Generate additional fields
    email = fake.email()
    phone = fake.phone_number()
    age = random.randint(22, 65)
    years_of_experience = random.randint(0, age - 21)  # assuming people start working at 21
    department = random.choices(list(DEPARTMENTS.keys()), weights=DEPARTMENTS.values(), k=1)[0]
    salary_range = SALARY_RANGES[department]
    salary = round(random.uniform(salary_range[0], salary_range[1]), 2)
    num_languages = random.choices([0, 1, 2], weights=[0.6, 0.3, 0.1], k=1)[0]
    languages_spoken = ", ".join(random.sample(LANGUAGES, num_languages))
    job_title = fake.job()

    employees.append({
        "First Name": first_name,
        "Last Name": last_name,
        "Email": email,
        "Phone": phone,
        "Gender": gender,
        "Age": age,
        "Job Title": job_title,
        "Years Of Experience": years_of_experience,
        "Salary": salary,
        "Department": department,
        "Languages": languages_spoken
    })

# Convert to DataFrame and save to CSV
df = pd.DataFrame(employees)
df.to_csv('/content/employee_2.csv', index=False)

# Generate profile for synthetic dataset
synthetic_profile = ProfileReport(df, title="Synthetic Dataset Profile", explorative=True)
synthetic_profile.to_file("synthetic_dataset_profile.html")

# Load the original dataset
original_df = pd.read_csv('/content/employee_1.csv')

# Generate profile for original dataset
original_profile = ProfileReport(original_df, title="Original Dataset Profile", explorative=True)
original_profile.to_file("original_dataset_profile.html")

# Print the columns to verify
print("Column names in the generated CSV file:")
print(df.columns)
# Out:
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.10/dist-packages (4.8.3)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.7.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions[type_image_path]<0.7.7,>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.25.2)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.1)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.58.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.6.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Column names in the generated CSV file:
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Gender', 'Age',
#        'Job Title', 'Years Of Experience', 'Salary', 'Department',
#        'Languages'],
#       dtype='object')
